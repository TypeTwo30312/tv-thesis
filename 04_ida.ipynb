# %%
import numpy as np
from pathlib import Path

cache_path = Path.home() / "vambersky_t/Data/exploration/cache"
# pick any one file to inspect
f = next(cache_path.rglob("*.derived.npz"))
print(f)
d = np.load(f, allow_pickle=False)
print(list(d.keys()))
print({k: d[k].shape for k in d.keys()})
# Out:
# /home/jovyan/vambersky_t/Data/exploration/cache/CTCF/ENCFF692RPA__CTCF__H1.derived.npz
# ['mean_pool', 'pos_profile', 'gc', 'gc_mean_profile', 'n_dropped']
# {'mean_pool': (9901, 4096), 'pos_profile': (200, 4096), 'gc': (9901, 200), 'gc_mean_profile': (200,), 'n_dropped': ()}
